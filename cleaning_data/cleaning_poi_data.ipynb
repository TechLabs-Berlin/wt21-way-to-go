# %%
import pandas as pd
import numpy as np
import json
import glob

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# #### If you don't have a merged poi dataset to read in, read in uncleaned Points of Interest data and merge into a single pandas dataframe:

# %%
#this code assumes you have the raw data in a folder titled 'poi_data', which should be in the same folder as this file
all_node_files = glob.glob('poi_data/' + '/*node.json')

li = []

for filename in all_node_files:
    data = json.load(open(filename))
    df = pd.DataFrame(data["elements"])
    li.append(df)

all_nodes = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Cleaning Points of Interest data

# %% [markdown]
# #### Exploring the data (first pass):

# %%
all_nodes.isna().sum()
# Out:
# type    0
# id      0
# lat     0
# lon     0
# tags    0
# dtype: int64

# %% [markdown]
# There are no missing values

# %% [markdown]
# ## Extracting relevant features

# %% [markdown]
# #### Extracting the name of each POI and adding it as a separate feature

# %%
# extracting the 'name' data and adding it to a new 'name' column 
def extract_name(df):
    new_df = df
    for i, dict in enumerate(new_df.tags):
        try:
            all_nodes.loc[i, 'name'] = dict['name']
        except:
            pass
    return new_df

# %% [markdown]
# #### Extracting relevant categories

# %%
"""
Function to extract categories from the 'tags' column of any version of the dataframe (must be parsed in as argument)

It contains the dictionary and loop from earlier category extraction.

A 'tags' column in its original raw form is a prerequisite. 
Pandas must be imported as pd and numpy as np.

Looping through keys should be enough, so I have added the extra lines back in.

I have included a line that will record 'historic: yes' categories as 'historic' rather than 'yes'.

"""

def extract_categories(df):
    
    # make a copy of the dataframe
    new_df = df
    
    # create a new 'category' column / fill it with empty lists
    new_df['category'] = np.empty((len(new_df), 0)).tolist()
    
    # dictionary of category key/value pairs that were scraped
    categories = {'amenity': ['atm',
                          'bar',
                          'bench',
                          'cafe',
                          'drinking_water',
                          'ice_cream',
                          'nightclub',
                          'restaurant'
                         ],
              
              'historic': ['yes'], # fixed bug to put all values into lists to avoid looping on strings
              'leisure': ['picnic_table'],
              'natural': ['tree'],
              'shop': ['convenience'],
              'tourism': ['art_work',
                          'attraction',
                          'gallery',
                          'museum',
                          'viewpoint',
                          ] 
              }

    # for the new df copy, loop through the 'tags' column, keeping track of the row index
    for index, row in enumerate(new_df.tags):        
        # for each row, loop through every key in the 'categories' dictionary
        for key in categories:
            # if the row contains a matching key
            if key in row:
                # if the key's value is equal to 'historic'
                if key == 'historic':
                    # for the current row, append 'historic' to the 'category' column
                    new_df.loc[index, 'category'].append('historic')
                else:
                    # check the key's value from the row against the key's values from the 'categories' variable
                    for value in categories[key]:
                        # if there is a match
                        if value in row[key]:
                            # for the current row, append the key's value to the 'category' column
                            new_df.loc[index, 'category'].append(value) # fixed bug to add matched value only
                     
    return new_df

# %% [markdown]
# #### Making a new 'lat_lgt' column with coordinate tuples

# %%
"""Extracts lat and lon values for each row and adds them to a new 'lat_lgt' column as a tuple
This matches the format of lat/lon data in the routes dataset """
def extract_lat_lgt_tuple(df):
    # create a copy of df
    new_df = df
    # create a new empty column 'lat_lgt' with dtype object (otherwise tuples won't be accepted as values)
    df['lat_lgt'] = pd.Series(dtype='object')
    # for every row
    for index in new_df.index:
        lat = df.loc[index, 'lat']
        lgt = df.loc[index, 'lon']
        # add the lat/lgt pairs as a tuple to the new column
        new_df.at[index, 'lat_lgt'] = (lat, lgt)                    
    return new_df

# %% [markdown]
# ## Creating the new dataframes

# %%
#'all_nodes' is the merged, uncleaned dataframe read in at the start of the file

all_nodes_extracted = extract_name(all_nodes)
all_nodes_extracted = extract_categories(all_nodes)
all_nodes_extracted = extract_lat_lgt_tuple(all_nodes)
all_nodes_extracted
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name     category                   lat_lgt
# 0       Bank für Sozialwirtschaft        [atm]  (52.5237445, 13.3986266)
# 1                     Sparda-Bank        [atm]  (52.5329853, 13.3842822)
# 2            Bankhaus August Lenz        [atm]  (52.5180249, 13.4069563)
# 3                             NaN        [atm]  (52.5421697, 13.4411367)
# 4              Berliner Sparkasse        [atm]  (52.5427503, 13.3928618)
# ...                           ...          ...                       ...
# 213006                        NaN  [viewpoint]  (52.4879893, 13.2753934)
# 213007                        NaN  [viewpoint]   (52.506772, 13.3345627)
# 213008                Alpengipfel  [viewpoint]  (52.4017038, 13.3669598)
# 213009                        NaN  [viewpoint]  (52.4821326, 13.2919107)
# 213010                        NaN  [viewpoint]   (52.3637638, 13.533663)
#
# [213011 rows x 8 columns]

# %% [markdown]
# ## Inspecting the full dataframe

# %% [markdown]
# #### Checking for double categories

# %%
double_categories = []
for index, value in enumerate(all_nodes_extracted.category):
    if len(value) > 1:
      
        double_categories.append(all_nodes_extracted.iloc[index])
        
print(len(double_categories))
print(double_categories)
# Out:
# 65
# [type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# lat_lgt                               (52.528762, 13.4086025)
# Name: 1041, dtype: object, type                                                     node
# id                                                  746853061
# lat                                                 52.580255
# lon                                                 13.398819
# tags        {'amenity': 'bar', 'internet_access': 'termina...
# name                                         Babylon Café Bar
# category                                   [bar, convenience]
# lat_lgt                              (52.5802548, 13.3988194)
# Name: 1098, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# lat_lgt                              (52.4820706, 13.4313317)
# Name: 1344, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# lat_lgt                              (52.5756588, 13.5622475)
# Name: 2305, dtype: object, type                                                     node
# id                                                  942863082
# lat                                                 52.357758
# lon                                                 13.472117
# tags        {'amenity': 'bench', 'backrest': 'yes', 'colou...
# name                                                      NaN
# category                                        [bench, tree]
# lat_lgt                               (52.3577581, 13.472117)
# Name: 2797, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# lat_lgt                              (52.6227615, 13.3396629)
# Name: 8365, dtype: object, type                                                     node
# id                                                  920664308
# lat                                                 52.498182
# lon                                                 13.384815
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Ökotussi
# category                                  [cafe, convenience]
# lat_lgt                              (52.4981816, 13.3848148)
# Name: 21289, dtype: object, type                                                     node
# id                                                 1397070387
# lat                                                 52.504943
# lon                                                 13.367928
# tags        {'amenity': 'cafe', 'name': 'Staabi Back & Bis...
# name                               Staabi Back & Bistro Kiosk
# category                                  [cafe, convenience]
# lat_lgt                              (52.5049434, 13.3679278)
# Name: 21498, dtype: object, type                                                     node
# id                                                 1400842135
# lat                                                 52.562455
# lon                                                 13.096985
# tags        {'addr:housenumber': '44', 'addr:postcode': '1...
# name                                               Biofreunde
# category                                  [cafe, convenience]
# lat_lgt                               (52.5624554, 13.096985)
# Name: 21499, dtype: object, type                                                     node
# id                                                 3855567146
# lat                                                 52.497329
# lon                                                 13.361518
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                    DiVan
# category                                  [cafe, convenience]
# lat_lgt                              (52.4973293, 13.3615177)
# Name: 22267, dtype: object, type                                                     node
# id                                                 6596706590
# lat                                                 52.545928
# lon                                                 13.344898
# tags        {'amenity': 'cafe', 'name': 'Von morgens bis S...
# name                                    Von morgens bis Späti
# category                                  [cafe, convenience]
# lat_lgt                              (52.5459278, 13.3448983)
# Name: 22987, dtype: object, type                                              node
# id                                          9201250436
# lat                                          52.571576
# lon                                           13.37374
# tags        {'amenity': 'cafe', 'shop': 'convenience'}
# name                                               NaN
# category                           [cafe, convenience]
# lat_lgt                       (52.5715757, 13.3737396)
# Name: 23319, dtype: object, type                                                     node
# id                                                 1110086631
# lat                                                  52.50532
# lon                                                 13.394087
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Super Ibérico
# category                            [restaurant, convenience]
# lat_lgt                              (52.5053204, 13.3940873)
# Name: 25336, dtype: object, type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# lat_lgt                               (52.528762, 13.4086025)
# Name: 28608, dtype: object, type                                                     node
# id                                                 2966005919
# lat                                                 52.508526
# lon                                                 13.379683
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Wachturm
# category                               [historic, attraction]
# lat_lgt                              (52.5085256, 13.3796834)
# Name: 28630, dtype: object, type                                                     node
# id                                                 6958744124
# lat                                                 52.514062
# lon                                                 13.711031
# tags        {'historic': 'yes', 'name': 'Gewölbekeller Bol...
# name                                Gewölbekeller Bollensdorf
# category                               [historic, attraction]
# lat_lgt                              (52.5140617, 13.7110308)
# Name: 28658, dtype: object, type                                                     node
# id                                                 6486438639
# lat                                                 52.483408
# lon                                                 13.186136
# tags        {'amenity': 'bench;table', 'leisure': 'picnic_...
# name                                                      NaN
# category                                [bench, picnic_table]
# lat_lgt                              (52.4834079, 13.1861365)
# Name: 28881, dtype: object, type                                                     node
# id                                                 6486438642
# lat                                                 52.484285
# lon                                                 13.185957
# tags        {'amenity': 'bench;table', 'leisure': 'picnic_...
# name                                                      NaN
# category                                [bench, picnic_table]
# lat_lgt                              (52.4842846, 13.1859568)
# Name: 28882, dtype: object, type                                                     node
# id                                                  205066401
# lat                                                 52.593577
# lon                                                 13.264907
# tags        {'circumference': '6.65', 'denotation': 'natur...
# name                                              Dicke Marie
# category                                   [tree, attraction]
# lat_lgt                               (52.593577, 13.2649068)
# Name: 29129, dtype: object, type                                                     node
# id                                                  268462839
# lat                                                 52.540259
# lon                                                 13.811659
# tags        {'name': 'Eiche', 'natural': 'tree', 'tourism'...
# name                                                    Eiche
# category                                   [tree, attraction]
# lat_lgt                               (52.540259, 13.8116595)
# Name: 29136, dtype: object, type                                                     node
# id                                                  518017139
# lat                                                 52.099379
# lon                                                 12.875652
# tags        {'name': 'Lutherlinde', 'natural': 'tree', 'to...
# name                                              Lutherlinde
# category                                   [tree, attraction]
# lat_lgt                              (52.0993786, 12.8756521)
# Name: 29482, dtype: object, type                                                     node
# id                                                  685046490
# lat                                                 52.369825
# lon                                                 13.271988
# tags        {'denotation': 'natural_monument', 'genus': 'T...
# name                                         Bernadotte Linde
# category                                   [tree, attraction]
# lat_lgt                              (52.3698251, 13.2719878)
# Name: 30394, dtype: object, type                                                     node
# id                                                  732329248
# lat                                                 52.655285
# lon                                                 13.070655
# tags        {'genus': 'Fagus', 'genus:de': 'Buche', 'leaf_...
# name                                       Zwölf Brüder Buche
# category                                   [tree, attraction]
# lat_lgt                              (52.6552852, 13.0706546)
# Name: 30638, dtype: object, type                                                     node
# id                                                  867885897
# lat                                                 52.501682
# lon                                                 13.415536
# tags        {'description': 'Gedenkbaum für die Opfer des ...
# name                                                      NaN
# category                                     [historic, tree]
# lat_lgt                              (52.5016821, 13.4155363)
# Name: 30663, dtype: object, type                                                     node
# id                                                  942863082
# lat                                                 52.357758
# lon                                                 13.472117
# tags        {'amenity': 'bench', 'backrest': 'yes', 'colou...
# name                                                      NaN
# category                                        [bench, tree]
# lat_lgt                               (52.3577581, 13.472117)
# Name: 30670, dtype: object, type                                                     node
# id                                                 1609064712
# lat                                                 52.595351
# lon                                                 13.243543
# tags        {'description': 'Höchster Baum Berlins', 'genu...
# name              Lärche, der höchste Baum Berlins mit 42,5 m
# category                                   [tree, attraction]
# lat_lgt                              (52.5953506, 13.2435433)
# Name: 34220, dtype: object, type                                                     node
# id                                                 2900844067
# lat                                                 52.427128
# lon                                                 13.048986
# tags        {'name': 'Baumhaus', 'natural': 'tree', 'playg...
# name                                                 Baumhaus
# category                                   [tree, attraction]
# lat_lgt                              (52.4271281, 13.0489856)
# Name: 50052, dtype: object, type                                                     node
# id                                                 2939703373
# lat                                                 52.260367
# lon                                                 13.202885
# tags        {'leaf_type': 'broadleaved', 'name': 'Mörderei...
# name                                              Mördereiche
# category                                   [tree, attraction]
# lat_lgt                               (52.2603665, 13.202885)
# Name: 50113, dtype: object, type                                                     node
# id                                                 3871338319
# lat                                                 52.394348
# lon                                                 13.061233
# tags        {'genus': 'Tilia', 'image': 'https://upload.wi...
# name                                       Bittschriftenlinde
# category                                   [tree, attraction]
# lat_lgt                                (52.394348, 13.061233)
# Name: 97723, dtype: object, type                                                     node
# id                                                 7146216585
# lat                                                 52.165527
# lon                                                 12.853716
# tags        {'description:de': 'Linde wurde anlässlich des...
# name                                              Luisenlinde
# category                                     [historic, tree]
# lat_lgt                              (52.1655269, 12.8537159)
# Name: 183443, dtype: object, type                                                     node
# id                                                  746853061
# lat                                                 52.580255
# lon                                                 13.398819
# tags        {'amenity': 'bar', 'internet_access': 'termina...
# name                                         Babylon Café Bar
# category                                   [bar, convenience]
# lat_lgt                              (52.5802548, 13.3988194)
# Name: 211502, dtype: object, type                                                     node
# id                                                  920664308
# lat                                                 52.498182
# lon                                                 13.384815
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Ökotussi
# category                                  [cafe, convenience]
# lat_lgt                              (52.4981816, 13.3848148)
# Name: 211522, dtype: object, type                                                     node
# id                                                 1110086631
# lat                                                  52.50532
# lon                                                 13.394087
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Super Ibérico
# category                            [restaurant, convenience]
# lat_lgt                              (52.5053204, 13.3940873)
# Name: 211534, dtype: object, type                                                     node
# id                                                 1397070387
# lat                                                 52.504943
# lon                                                 13.367928
# tags        {'amenity': 'cafe', 'name': 'Staabi Back & Bis...
# name                               Staabi Back & Bistro Kiosk
# category                                  [cafe, convenience]
# lat_lgt                              (52.5049434, 13.3679278)
# Name: 211588, dtype: object, type                                                     node
# id                                                 1400842135
# lat                                                 52.562455
# lon                                                 13.096985
# tags        {'addr:housenumber': '44', 'addr:postcode': '1...
# name                                               Biofreunde
# category                                  [cafe, convenience]
# lat_lgt                               (52.5624554, 13.096985)
# Name: 211590, dtype: object, type                                                     node
# id                                                 2496841605
# lat                                                 52.510136
# lon                                                 13.458375
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                              Quick Store Aquarium Lounge
# category                                  [cafe, convenience]
# lat_lgt                              (52.5101364, 13.4583749)
# Name: 211728, dtype: object, type                                                     node
# id                                                 3855567146
# lat                                                 52.497329
# lon                                                 13.361518
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                    DiVan
# category                                  [cafe, convenience]
# lat_lgt                              (52.4973293, 13.3615177)
# Name: 211853, dtype: object, type                                                     node
# id                                                 3914046328
# lat                                                 52.452421
# lon                                                   13.3334
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 @lbrecht
# category                                  [cafe, convenience]
# lat_lgt                              (52.4524213, 13.3333997)
# Name: 211865, dtype: object, type                                                     node
# id                                                 4331556368
# lat                                                 52.481255
# lon                                                 13.320116
# tags        {'amenity': 'internet_cafe', 'internet_access'...
# name                          Aris Internet-Spätkauf & Presse
# category                                  [cafe, convenience]
# lat_lgt                              (52.4812552, 13.3201158)
# Name: 211927, dtype: object, type                                                     node
# id                                                 6596706590
# lat                                                 52.545928
# lon                                                 13.344898
# tags        {'amenity': 'cafe', 'name': 'Von morgens bis S...
# name                                    Von morgens bis Späti
# category                                  [cafe, convenience]
# lat_lgt                              (52.5459278, 13.3448983)
# Name: 212129, dtype: object, type                                                     node
# id                                                 8147270778
# lat                                                 52.480708
# lon                                                 13.351453
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                Fast Shop
# category                                  [cafe, convenience]
# lat_lgt                               (52.480708, 13.3514527)
# Name: 212216, dtype: object, type                                              node
# id                                          9201250436
# lat                                          52.571576
# lon                                           13.37374
# tags        {'amenity': 'cafe', 'shop': 'convenience'}
# name                                               NaN
# category                           [cafe, convenience]
# lat_lgt                       (52.5715757, 13.3737396)
# Name: 212287, dtype: object, type                                                     node
# id                                                   51501652
# lat                                                 52.655049
# lon                                                 13.719846
# tags        {'historic': 'memorial', 'name': 'Gedenkstätte...
# name                   Gedenkstätte Internierungslager Weesow
# category                               [historic, attraction]
# lat_lgt                              (52.6550495, 13.7198461)
# Name: 212293, dtype: object, type                                                     node
# id                                                  205066401
# lat                                                 52.593577
# lon                                                 13.264907
# tags        {'circumference': '6.65', 'denotation': 'natur...
# name                                              Dicke Marie
# category                                   [tree, attraction]
# lat_lgt                               (52.593577, 13.2649068)
# Name: 212296, dtype: object, type                                                     node
# id                                                  267113400
# lat                                                  52.31816
# lon                                                 13.632617
# tags        {'description': 'technical_monument', 'histori...
# name                                    Dampflokomotive BR 52
# category                               [historic, attraction]
# lat_lgt                              (52.3181599, 13.6326174)
# Name: 212297, dtype: object, type                                                     node
# id                                                  268462839
# lat                                                 52.540259
# lon                                                 13.811659
# tags        {'name': 'Eiche', 'natural': 'tree', 'tourism'...
# name                                                    Eiche
# category                                   [tree, attraction]
# lat_lgt                               (52.540259, 13.8116595)
# Name: 212298, dtype: object, type                                                     node
# id                                                  518017139
# lat                                                 52.099379
# lon                                                 12.875652
# tags        {'name': 'Lutherlinde', 'natural': 'tree', 'to...
# name                                              Lutherlinde
# category                                   [tree, attraction]
# lat_lgt                              (52.0993786, 12.8756521)
# Name: 212309, dtype: object, type                                                     node
# id                                                  558158766
# lat                                                 52.540486
# lon                                                 13.489519
# tags        {'historic': 'memorial', 'memorial': 'war_memo...
# name                                    Sowjetisches Ehrenmal
# category                               [historic, attraction]
# lat_lgt                              (52.5404864, 13.4895185)
# Name: 212311, dtype: object, type                                                     node
# id                                                  639131685
# lat                                                 52.418807
# lon                                                 13.171892
# tags        {'historic': 'memorial', 'image': 'http://comm...
# name                                               Kleistgrab
# category                               [historic, attraction]
# lat_lgt                              (52.4188074, 13.1718917)
# Name: 212316, dtype: object, type                                                     node
# id                                                  685046490
# lat                                                 52.369825
# lon                                                 13.271988
# tags        {'denotation': 'natural_monument', 'genus': 'T...
# name                                         Bernadotte Linde
# category                                   [tree, attraction]
# lat_lgt                              (52.3698251, 13.2719878)
# Name: 212317, dtype: object, type                                                     node
# id                                                  732329248
# lat                                                 52.655285
# lon                                                 13.070655
# tags        {'genus': 'Fagus', 'genus:de': 'Buche', 'leaf_...
# name                                       Zwölf Brüder Buche
# category                                   [tree, attraction]
# lat_lgt                              (52.6552852, 13.0706546)
# Name: 212319, dtype: object, type                                                     node
# id                                                 1166456006
# lat                                                 52.430757
# lon                                                 13.311793
# tags        {'description': 'Historische Treidellokomotive...
# name                                        Treidellokomotive
# category                               [historic, attraction]
# lat_lgt                              (52.4307575, 13.3117928)
# Name: 212322, dtype: object, type                                                     node
# id                                                 1589171931
# lat                                                 52.478944
# lon                                                 13.344614
# tags        {'description:de': 'Preußischer Ganzmeilenstei...
# name                                  Preußischer Meilenstein
# category                               [historic, attraction]
# lat_lgt                              (52.4789437, 13.3446144)
# Name: 212326, dtype: object, type                                                     node
# id                                                 1609064712
# lat                                                 52.595351
# lon                                                 13.243543
# tags        {'description': 'Höchster Baum Berlins', 'genu...
# name              Lärche, der höchste Baum Berlins mit 42,5 m
# category                                   [tree, attraction]
# lat_lgt                              (52.5953506, 13.2435433)
# Name: 212327, dtype: object, type                                                     node
# id                                                 2787929162
# lat                                                 52.408512
# lon                                                 13.302128
# tags        {'historic': 'memorial', 'memorial': 'plaque',...
# name                                 TV-Asahi-Kirschblütenweg
# category                               [historic, attraction]
# lat_lgt                              (52.4085121, 13.3021284)
# Name: 212344, dtype: object, type                                                     node
# id                                                 2900844067
# lat                                                 52.427128
# lon                                                 13.048986
# tags        {'name': 'Baumhaus', 'natural': 'tree', 'playg...
# name                                                 Baumhaus
# category                                   [tree, attraction]
# lat_lgt                              (52.4271281, 13.0489856)
# Name: 212353, dtype: object, type                                                     node
# id                                                 2939703373
# lat                                                 52.260367
# lon                                                 13.202885
# tags        {'leaf_type': 'broadleaved', 'name': 'Mörderei...
# name                                              Mördereiche
# category                                   [tree, attraction]
# lat_lgt                               (52.2603665, 13.202885)
# Name: 212355, dtype: object, type                                                     node
# id                                                 2966005919
# lat                                                 52.508526
# lon                                                 13.379683
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Wachturm
# category                               [historic, attraction]
# lat_lgt                              (52.5085256, 13.3796834)
# Name: 212356, dtype: object, type                                                     node
# id                                                 3871338319
# lat                                                 52.394348
# lon                                                 13.061233
# tags        {'genus': 'Tilia', 'image': 'https://upload.wi...
# name                                       Bittschriftenlinde
# category                                   [tree, attraction]
# lat_lgt                                (52.394348, 13.061233)
# Name: 212360, dtype: object, type                                                     node
# id                                                 4844728421
# lat                                                 52.509901
# lon                                                 13.376312
# tags        {'description': 'Remains of the Berlin Wall', ...
# name                                                      NaN
# category                               [historic, attraction]
# lat_lgt                              (52.5099014, 13.3763121)
# Name: 212367, dtype: object, type                                                     node
# id                                                 5479192054
# lat                                                 52.477594
# lon                                                 13.402207
# tags        {'historic': 'aircraft', 'name': 'Übungsflugze...
# name                    Übungsflugzeug der Flughafenfeuerwehr
# category                               [historic, attraction]
# lat_lgt                              (52.4775939, 13.4022072)
# Name: 212375, dtype: object, type                                                     node
# id                                                 6958744124
# lat                                                 52.514062
# lon                                                 13.711031
# tags        {'historic': 'yes', 'name': 'Gewölbekeller Bol...
# name                                Gewölbekeller Bollensdorf
# category                               [historic, attraction]
# lat_lgt                              (52.5140617, 13.7110308)
# Name: 212387, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# lat_lgt                              (52.5756588, 13.5622475)
# Name: 212818, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# lat_lgt                              (52.4820706, 13.4313317)
# Name: 212895, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# lat_lgt                              (52.6227615, 13.3396629)
# Name: 212933, dtype: object]

# %% [markdown]
# *There are 65 rows with multiple categories, all of which are instances of the desired scraped categories!*

# %% [markdown]
# #### Checking for null values

# %%
# checking for missing values
all_nodes_extracted.isna().sum()
# Out:
# type             0
# id               0
# lat              0
# lon              0
# tags             0
# name        202443
# category         0
# lat_lgt          0
# dtype: int64

# %% [markdown]
# *There are 202443 rows that don't have a name - this will need to be accounted for if names will be displayed in the final product*

# %% [markdown]
# #### Check the number of categories (double categories are excluded)

# %%
all_nodes_extracted['category'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [tree]                       182285
# [bench]                       19024
# [restaurant]                   4685
# [cafe]                         2475
# [atm]                          1011
# [convenience]                   869
# [bar]                           818
# [picnic_table]                  434
# [ice_cream]                     289
# [viewpoint]                     256
# [gallery]                       189
# [museum]                        156
# [drinking_water]                148
# [nightclub]                     141
# [attraction]                     94
# [historic]                       72
# [tree, attraction]               18
# [cafe, convenience]              16
# [historic, attraction]           13
# [bench, viewpoint]                4
# [bar, historic]                   2
# [bench, picnic_table]             2
# [historic, tree]                  2
# [restaurant, convenience]         2
# [bar, convenience]                2
# [bench, tree]                     2
# [bar, viewpoint]                  2
# Name: category, dtype: int64

# %% [markdown]
# ### Inspecting the cleaned dataset

# %%
all_nodes_extracted.sort_values(by='lat')
# Out:
#         type          id        lat        lon  \
# 25859   node  1767860179  52.049367  12.897805
# 16458   node  7809140205  52.056699  12.890166
# 136263  node  4867051858  52.056718  12.947945
# 136261  node  4867051856  52.056942  12.947483
# 136262  node  4867051857  52.056995  12.947478
# ...      ...         ...        ...        ...
# 177138  node  6210317133  52.726197  13.504110
# 118784  node  4069649001  52.738323  13.294171
# 118785  node  4069649010  52.738795  13.290276
# 79524   node  3647555641  52.749586  13.289174
# 212940  node  5031849563  52.757041  13.275634
#
#                                                      tags  \
# 25859   {'addr:city': 'Treuenbrietzen', 'addr:housenum...
# 16458   {'amenity': 'bench', 'backrest': 'yes', 'mater...
# 136263  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...
# 136261  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...
# 136262  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...
# ...                                                   ...
# 177138  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...
# 118784         {'name': 'Kaisereiche', 'natural': 'tree'}
# 118785          {'name': 'Zareneiche', 'natural': 'tree'}
# 79524   {'description': 'markanter toter Baum', 'descr...
# 212940  {'name': 'Aussicht auf den Lehnitzsee', 'touri...
#
#                                name      category                   lat_lgt
# 25859               Zur alten Eiche  [restaurant]  (52.0493672, 12.8978051)
# 16458                           NaN       [bench]   (52.056699, 12.8901664)
# 136263                          NaN        [tree]  (52.0567179, 12.9479447)
# 136261                          NaN        [tree]  (52.0569422, 12.9474833)
# 136262                          NaN        [tree]    (52.056995, 12.947478)
# ...                             ...           ...                       ...
# 177138                          100        [tree]     (52.726197, 13.50411)
# 118784                  Kaisereiche        [tree]   (52.738323, 13.2941708)
# 118785                   Zareneiche        [tree]  (52.7387954, 13.2902757)
# 79524                           NaN        [tree]  (52.7495864, 13.2891739)
# 212940  Aussicht auf den Lehnitzsee   [viewpoint]  (52.7570405, 13.2756342)
#
# [213011 rows x 8 columns]

# %%
all_nodes_extracted.sort_values(by='lon')
# Out:
#         type          id        lat        lon  \
# 190098  node  8357706309  52.113896  12.813895
# 190097  node  8357706308  52.113984  12.814045
# 190099  node  8357706310  52.113648  12.814063
# 190096  node  8357706307  52.114133  12.814331
# 190100  node  8357706311  52.113413  12.814358
# ...      ...         ...        ...        ...
# 123335  node  4456998785  52.591379  13.973305
# 123331  node  4456986483  52.613533  13.974341
# 123332  node  4456986498  52.607256  13.978784
# 123336  node  4457068147  52.575151  13.986716
# 123337  node  4457122513  52.593067  14.019910
#
#                                                      tags name category  \
# 190098  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...  NaN   [tree]
# 190097  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...  NaN   [tree]
# 190099  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...  NaN   [tree]
# 190096  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...  NaN   [tree]
# 190100  {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...  NaN   [tree]
# ...                                                   ...  ...      ...
# 123335                                {'natural': 'tree'}  NaN   [tree]
# 123331                                {'natural': 'tree'}  NaN   [tree]
# 123332                                {'natural': 'tree'}  NaN   [tree]
# 123336                                {'natural': 'tree'}  NaN   [tree]
# 123337                                {'natural': 'tree'}  NaN   [tree]
#
#                          lat_lgt
# 190098  (52.1138959, 12.8138946)
# 190097  (52.1139844, 12.8140453)
# 190099  (52.1136476, 12.8140628)
# 190096  (52.1141327, 12.8143305)
# 190100  (52.1134134, 12.8143578)
# ...                          ...
# 123335   (52.5913789, 13.973305)
# 123331  (52.6135334, 13.9743414)
# 123332  (52.6072561, 13.9787835)
# 123336  (52.5751515, 13.9867155)
# 123337   (52.593067, 14.0199095)
#
# [213011 rows x 8 columns]

# %% [markdown]
# *A lot of the data points are outside the boundary of Berlin!*

# %% [markdown]
# #### (Optional!) Function to filter non-Berlin POIs
#
# Unsure how much computation this would save. Likely that we could leave this unfiltered, since all poi that do not match a route are unlikely to be kept at merging.

# %%
"""copy with Emilio's lat/lon boundaries
def berlin_only(df):
    
    new_df = df
    
    filt = new_df['lat'] > 52.3 #& new_df['lat'] < 52.68 & new_df['lon'] > 13.09 & new_df['lon'] < 13.77
    new_df = new_df.loc[filt]
    
    filt = new_df['lat'] < 52.7
    new_df = new_df.loc[filt]
    
    filt = new_df['lon'] > 12.9
    new_df = new_df.loc[filt]
    
    filt = new_df['lon'] < 13.77
    new_df = new_df.loc[filt]
    
    return new_df
"""

# %%
#filter function with Stefanie's lat/lon values
def berlin_only(df):
    
    new_df = df
    
    filt = new_df['lat'] > 52.3 #& new_df['lat'] < 52.68 & new_df['lon'] > 13.09 & new_df['lon'] < 13.77
    new_df = new_df.loc[filt]
    
    filt = new_df['lat'] < 52.7
    new_df = new_df.loc[filt]
    
    filt = new_df['lon'] > 12.9
    new_df = new_df.loc[filt]
    
    filt = new_df['lon'] < 13.7
    new_df = new_df.loc[filt]
    
    return new_df

# %%
all_nodes_extracted_berlin_only = berlin_only(all_nodes_extracted)
all_nodes_extracted_berlin_only
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name     category                   lat_lgt
# 0       Bank für Sozialwirtschaft        [atm]  (52.5237445, 13.3986266)
# 1                     Sparda-Bank        [atm]  (52.5329853, 13.3842822)
# 2            Bankhaus August Lenz        [atm]  (52.5180249, 13.4069563)
# 3                             NaN        [atm]  (52.5421697, 13.4411367)
# 4              Berliner Sparkasse        [atm]  (52.5427503, 13.3928618)
# ...                           ...          ...                       ...
# 213006                        NaN  [viewpoint]  (52.4879893, 13.2753934)
# 213007                        NaN  [viewpoint]   (52.506772, 13.3345627)
# 213008                Alpengipfel  [viewpoint]  (52.4017038, 13.3669598)
# 213009                        NaN  [viewpoint]  (52.4821326, 13.2919107)
# 213010                        NaN  [viewpoint]   (52.3637638, 13.533663)
#
# [207531 rows x 8 columns]

# %%
213011-207531
# Out:
# 5480

# %% [markdown]
# *The berlin_only filter with current parameters filters out 5480 POIs. This is likely to be negligible in terms of computational cost*

# %% [markdown]
# ## Writing the cleaned dataframe

# %% [markdown]
# #### 1. Make a copy with desired columns

# %%
# Columns based on latest stand that geopandas requires lat and lon as separate features
# Dataframe is not currently filtered for lat/lon boundaries
cleaned_all_poi_data = all_nodes_extracted[['category', 'name', 'id', 'lat', 'lon']] 
cleaned_all_poi_data
# Out:
#            category                       name          id        lat  \
# 0             [atm]  Bank für Sozialwirtschaft    78252154  52.523744
# 1             [atm]                Sparda-Bank    87036263  52.532985
# 2             [atm]       Bankhaus August Lenz    89275133  52.518025
# 3             [atm]                        NaN   213106623  52.542170
# 4             [atm]         Berliner Sparkasse   213113204  52.542750
# ...             ...                        ...         ...        ...
# 213006  [viewpoint]                        NaN  8931299152  52.487989
# 213007  [viewpoint]                        NaN  9024702237  52.506772
# 213008  [viewpoint]                Alpengipfel  9026936271  52.401704
# 213009  [viewpoint]                        NaN  9038673666  52.482133
# 213010  [viewpoint]                        NaN  9180246277  52.363764
#
#               lon
# 0       13.398627
# 1       13.384282
# 2       13.406956
# 3       13.441137
# 4       13.392862
# ...           ...
# 213006  13.275393
# 213007  13.334563
# 213008  13.366960
# 213009  13.291911
# 213010  13.533663
#
# [213011 rows x 5 columns]

# %% [markdown]
# #### 2. Write the cleaned dataset to file (choose json to retain list functionality)

# %%
cleaned_all_poi_data.to_csv('cleaned_all_poi_data.csv')
cleaned_all_poi_data.to_json('cleaned_all_poi_data.json')
