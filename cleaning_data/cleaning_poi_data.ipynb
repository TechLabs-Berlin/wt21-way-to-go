# %%
import pandas as pd
import numpy as np
import json
import glob

# %% [markdown]
# # Cleaning Points of Interest data

# %% [markdown]
# #### Read in uncleaned Points of Interest data and merge into a single pandas dataframe:

# %%
#this code assumes you have the raw data in a folder titled 'poi_data', which should be in the same folder as this file
all_node_files = glob.glob('poi_data/' + '/*node.json')

li = []

for filename in all_node_files:
    data = json.load(open(filename))
    df = pd.DataFrame(data["elements"])
    li.append(df)

all_nodes = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# #### Exploring the data with basic cleaning methods (first pass):

# %%
all_nodes.dropna()
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
# [213011 rows x 5 columns]

# %% [markdown]
# There are no missing values

# %% [markdown]
# ## Extracting relevant features from 'tags' attribute

# %% [markdown]
# #### Extracting the name of each POI and adding it as a separate feature

# %%
# extracting the 'name' data and adding it to a new 'name' column 
for i, dict in enumerate(all_nodes.tags):
    try:
        all_nodes.loc[i, 'name'] = dict['name']
    except:
        pass

all_nodes
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name
# 0       Bank für Sozialwirtschaft
# 1                     Sparda-Bank
# 2            Bankhaus August Lenz
# 3                             NaN
# 4              Berliner Sparkasse
# ...                           ...
# 213006                        NaN
# 213007                        NaN
# 213008                Alpengipfel
# 213009                        NaN
# 213010                        NaN
#
# [213011 rows x 6 columns]

# %% [markdown]
# ### Extracting relevant categories

# %%
# dictionary of category key/value pairs that were scraped
categories = {'amenity': ['atm',
                          'bar',
                          'bench',
                          'cafe',
                          'drinking_water',
                          'ice_cream',
                          'nightclub',
                          'restaurant'
                         ],
              
              'historic': 'yes',
              'leisure': 'picnic_table',
              'natural': 'tree',
              'shop':'convenience',
              'tourism': ['art_work',
                          'attraction',
                          'gallery',
                          'museum',
                          'viewpoint',
                          ]
              }

# %%
# loop through every row in all_nodes.tags, keeping track of the index
for index, row in enumerate(all_nodes.tags):
    # for each row, loop through every key from the 'categories' variable 
    for key in categories:
        # if the row contains a matching key    
        if key in row:
            # check the key's value from the row against the key's values from the 'categories' variable
            for value in categories[key]:
                # if these check out
                if value in row[key]:
                    # for the current row, add the value to a new 'category' column
                    all_nodes.loc[index, 'category'] = row[key]

# %% [markdown]
# ## Inspecting the data

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
all_nodes.category
# Out:
# 0               atm
# 1               atm
# 2               atm
# 3               atm
# 4               atm
#             ...
# 213006    viewpoint
# 213007    viewpoint
# 213008    viewpoint
# 213009    viewpoint
# 213010    viewpoint
# Name: category, Length: 213011, dtype: object

# %%
all_nodes.loc[150000]
# Out:
# type                                                     node
# id                                                 5322155730
# lat                                                 52.475372
# lon                                                 13.289718
# tags        {'leaf_cycle': 'deciduous', 'leaf_type': 'broa...
# name                                                      NaN
# category                                                 tree
# Name: 150000, dtype: object

# %% [markdown]
# #### Writing the updated dataframe to csv and json

# %%
all_nodes.to_json('all_nodes_with_categories.json')

# %%
all_nodes.to_csv('all_nodes_with_categories.csv')

# %% [markdown]
# # Continue from here
# Reading in all_nodes_with_categories

# %%
all_nodes_with_categories = pd.read_json('all_nodes_with_categories.json')

# %%
all_nodes_with_categories
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name   category
# 0       Bank für Sozialwirtschaft        atm
# 1                     Sparda-Bank        atm
# 2            Bankhaus August Lenz        atm
# 3                            None        atm
# 4              Berliner Sparkasse        atm
# ...                           ...        ...
# 213006                       None  viewpoint
# 213007                       None  viewpoint
# 213008                Alpengipfel  viewpoint
# 213009                       None  viewpoint
# 213010                       None  viewpoint
#
# [213011 rows x 7 columns]

# %%
all_nodes_with_categories.name.isna().sum()
# Out:
# 202443

# %% [markdown]
# 202443 missing values in 'name'

# %%
all_nodes_with_categories.category.isna().sum()
# Out:
# 0

# %% [markdown]
# No missing values in 'category'

# %% [markdown]
# # Category extraction rerun

# %% [markdown]
# I realised that if any rows had multiple categories, this would not have been capture by the previous code. Therefore I decided to edit the code and rerun the category extraction.

# %% [markdown]
# # Version 2

# %%
"""
Function to extract categories from the 'tags' column of any version of the dataframe (must be parsed in as argument)

It contains the dictionary and loop from earlier category extraction.

A 'tags' column in its original raw form is a prerequisite. 
Pandas must be imported as pd and numpy as np.

To reduce computational cost, I have removed lines from the loop looping for the specific category value, 
since the data should contain only values that were scraped for. 
Looping through keys should be enough.

I have also added a line that will record 'historic: yes' categories as 'historic' rather than 'yes'.

"""

def extract_categories(df):
    
    # make a copy of the dataframe
    new_df = df
    
    # create a new 'category' column / fill it with empty lists
    new_df['category'] = np.empty((len(new_df), 0)).tolist()
    
    # dictionary of category key/value pairs that were scraped
    categories = {'amenity': ['atm',
                          'bar',
                          'bench',
                          'cafe',
                          'drinking_water',
                          'ice_cream',
                          'nightclub',
                          'restaurant'
                         ],
              
              'historic': 'yes',
              'leisure': 'picnic_table',
              'natural': 'tree',
              'shop':'convenience',
              'tourism': ['art_work',
                          'attraction',
                          'gallery',
                          'museum',
                          'viewpoint',
                          ]
              }

    # for the new df copy, loop through the 'tags' column, keeping track of the row index
    for index, row in enumerate(new_df.tags):        
        # for each row, loop through every key from the 'categories' variable
        for key in categories:
            # if the row contains a matching key
            if key in row:
                # if the key's value is equal to 'historic'
                if key == 'historic':
                    # for the current row, append 'historic' to the 'category' column
                    new_df.loc[index, 'category'].append('historic')
                else:
                    # for the current row, append the key's value to the 'category' column
                    new_df.loc[index, 'category'].append(row[key])
 
    return new_df

# %%
version2 = extract_categories(all_nodes)
version2
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name     category
# 0       Bank für Sozialwirtschaft        [atm]
# 1                     Sparda-Bank        [atm]
# 2            Bankhaus August Lenz        [atm]
# 3                             NaN        [atm]
# 4              Berliner Sparkasse        [atm]
# ...                           ...          ...
# 213006                        NaN  [viewpoint]
# 213007                        NaN  [viewpoint]
# 213008                Alpengipfel  [viewpoint]
# 213009                        NaN  [viewpoint]
# 213010                        NaN  [viewpoint]
#
# [213011 rows x 7 columns]

# %%
version1 = all_nodes_with_categories
version1
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name   category
# 0       Bank für Sozialwirtschaft        atm
# 1                     Sparda-Bank        atm
# 2            Bankhaus August Lenz        atm
# 3                            None        atm
# 4              Berliner Sparkasse        atm
# ...                           ...        ...
# 213006                       None  viewpoint
# 213007                       None  viewpoint
# 213008                Alpengipfel  viewpoint
# 213009                       None  viewpoint
# 213010                       None  viewpoint
#
# [213011 rows x 7 columns]

# %%
double_categories = []
for index, value in enumerate(version2.category):
    if len(value) > 1:
        
        double_categories.append(version2.iloc[index])
        
print(double_categories)
len(double_categories)
# Out:
# [type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# Name: 1041, dtype: object, type                                                     node
# id                                                  667858502
# lat                                                 52.503265
# lon                                                 13.412501
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Hürrem Sultan
# category                                        [bar, tailor]
# Name: 1083, dtype: object, type                                                     node
# id                                                  746853061
# lat                                                 52.580255
# lon                                                 13.398819
# tags        {'amenity': 'bar', 'internet_access': 'termina...
# name                                         Babylon Café Bar
# category                                   [bar, convenience]
# Name: 1098, dtype: object, type                                                     node
# id                                                 2541047698
# lat                                                 52.470828
# lon                                                 13.441197
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                               Café & Bar
# category                           [bar, adult_gaming_center]
# Name: 1303, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# Name: 1344, dtype: object, type                                                     node
# id                                                 3749393119
# lat                                                 52.487139
# lon                                                 13.431013
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '5...
# name                               La BarBer Queer Tattoo Bar
# category                                   [bar, hairdresser]
# Name: 1419, dtype: object, type                                                     node
# id                                                 4224268262
# lat                                                 52.542646
# lon                                                 13.356982
# tags        {'amenity': 'bar', 'name': 'Shikgoo Café & Bar...
# name                                       Shikgoo Café & Bar
# category                                 [bar, travel_agency]
# Name: 1498, dtype: object, type                                                     node
# id                                                 7195094856
# lat                                                 52.493708
# lon                                                 13.507892
# tags        {'amenity': 'bar', 'name': 'Sports Bar', 'open...
# name                                               Sports Bar
# category                                        [bar, vacant]
# Name: 1749, dtype: object, type                                                  node
# id                                               537038503
# lat                                              52.677689
# lon                                              13.577944
# tags        {'amenity': 'bench', 'tourism': 'picnic_site'}
# name                                                   NaN
# category                              [bench, picnic_site]
# Name: 2028, dtype: object, type                                                     node
# id                                                  691178664
# lat                                                 52.573711
# lon                                                 13.480029
# tags        {'amenity': 'bench', 'backrest': 'yes', 'check...
# name                                                      NaN
# category                                 [bench, picnic_site]
# Name: 2252, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 2305, dtype: object, type                                                  node
# id                                               773672716
# lat                                               52.32013
# lon                                              13.626975
# tags        {'amenity': 'bench', 'tourism': 'picnic_site'}
# name                                                   NaN
# category                              [bench, picnic_site]
# Name: 2392, dtype: object, type                                                     node
# id                                                  942863082
# lat                                                 52.357758
# lon                                                 13.472117
# tags        {'amenity': 'bench', 'backrest': 'yes', 'colou...
# name                                                      NaN
# category                                        [bench, tree]
# Name: 2797, dtype: object, type                                                     node
# id                                                 1364468283
# lat                                                 52.237321
# lon                                                 13.008223
# tags        {'amenity': 'bench', 'backrest': 'no', 'materi...
# name                                                      NaN
# category                                 [bench, picnic_site]
# Name: 3399, dtype: object, type                                                     node
# id                                                 2525150014
# lat                                                 52.595827
# lon                                                 13.838731
# tags        {'amenity': 'bench', 'backrest': 'yes', 'touri...
# name                                                      NaN
# category                                 [bench, picnic_site]
# Name: 4828, dtype: object, type                                                  node
# id                                              2878256947
# lat                                              52.492399
# lon                                              13.068094
# tags        {'amenity': 'bench', 'tourism': 'picnic_site'}
# name                                                   NaN
# category                              [bench, picnic_site]
# Name: 5246, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 8365, dtype: object, type                                                     node
# id                                                 6396622853
# lat                                                 52.326893
# lon                                                  13.41871
# tags        {'amenity': 'bench', 'backrest': 'no', 'materi...
# name                                                      NaN
# category                                     [bench, artwork]
# Name: 13562, dtype: object, type                                                     node
# id                                                   81362508
# lat                                                 52.508907
# lon                                                 13.270851
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                           Café & Reisebüro - Eishandwerk
# category                                [cafe, travel_agency]
# Name: 20866, dtype: object, type                                                     node
# id                                                  269713585
# lat                                                 52.518394
# lon                                                 13.346415
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '1...
# name                Weinwirtschaft in der Akademie der Künste
# category                                         [cafe, wine]
# Name: 20881, dtype: object, type                                                     node
# id                                                  272811519
# lat                                                 52.497988
# lon                                                 13.443644
# tags        {'amenity': 'cafe', 'created_by': 'Potlatch 0....
# name                                               Bizim Kiez
# category                                       [cafe, bakery]
# Name: 20886, dtype: object, type                                                     node
# id                                                  272812495
# lat                                                 52.497131
# lon                                                 13.443152
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                             Beumer Lutum
# category                                       [cafe, bakery]
# Name: 20887, dtype: object, type                                                     node
# id                                                  282430727
# lat                                                 52.516026
# lon                                                 13.457021
# tags        {'amenity': 'cafe', 'name': 'Café Tasso', 'ope...
# name                                               Café Tasso
# category                                        [cafe, books]
# Name: 20899, dtype: object, type                                                     node
# id                                                  292203637
# lat                                                 52.497895
# lon                                                 13.323003
# tags        {'amenity': 'cafe', 'drink:wine': 'retail', 'n...
# name                                                Ottenthal
# category                                      [cafe, alcohol]
# Name: 20909, dtype: object, type                                                     node
# id                                                  308626327
# lat                                                 52.549783
# lon                                                 13.416979
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                               Mühlenbäck
# category                                       [cafe, bakery]
# Name: 20917, dtype: object, type                                                     node
# id                                                  391769942
# lat                                                 52.095599
# lon                                                 12.870245
# tags        {'addr:housenumber': '16', 'addr:postcode': '1...
# name                                               Sieberhein
# category                                       [cafe, bakery]
# Name: 20973, dtype: object, type                                                     node
# id                                                  473629401
# lat                                                  52.55781
# lon                                                 13.390036
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                             Ege One Cafe
# category                                       [cafe, bakery]
# Name: 21031, dtype: object, type                                                     node
# id                                                  570034727
# lat                                                  52.45181
# lon                                                  13.33047
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                        Konditorei Rabien
# category                                       [cafe, pastry]
# Name: 21073, dtype: object, type                                                     node
# id                                                  607756448
# lat                                                 52.540153
# lon                                                 13.375365
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                Cafe Desd
# category                                       [cafe, bakery]
# Name: 21082, dtype: object, type                                                     node
# id                                                  619366460
# lat                                                 52.514704
# lon                                                 13.390455
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '2...
# name                                         Bunte SchokoWelt
# category                                [cafe, confectionery]
# Name: 21099, dtype: object, type                                                     node
# id                                                  636094595
# lat                                                 52.399607
# lon                                                 13.049019
# tags        {'access': 'customers', 'addr:city': 'Potsdam'...
# name                                Bäckerei & Café Steinecke
# category                                       [cafe, bakery]
# Name: 21112, dtype: object, type                                                     node
# id                                                  654401099
# lat                                                 52.510446
# lon                                                   13.4541
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                    Spielwiese "Ludothek"
# category                                        [cafe, games]
# Name: 21126, dtype: object, type                                                     node
# id                                                  655146770
# lat                                                 52.512255
# lon                                                 13.485236
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                 Beck's Bäckerei & Bistro
# category                                       [cafe, bakery]
# Name: 21127, dtype: object, type                                                     node
# id                                                  661126968
# lat                                                   52.5153
# lon                                                 13.304619
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                         Schlesische Backstube Hutzelmann
# category                                       [cafe, bakery]
# Name: 21131, dtype: object, type                                                     node
# id                                                  670658006
# lat                                                 52.480459
# lon                                                 13.352005
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                              Hak Bakery & Breakfasthouse
# category                                       [cafe, bakery]
# Name: 21142, dtype: object, type                                                     node
# id                                                  678901089
# lat                                                 52.457886
# lon                                                 13.292746
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Kornfeld
# category                                       [cafe, bakery]
# Name: 21151, dtype: object, type                                         node
# id                                      691415149
# lat                                      52.71591
# lon                                     13.437989
# tags        {'amenity': 'cafe', 'shop': 'bakery'}
# name                                          NaN
# category                           [cafe, bakery]
# Name: 21158, dtype: object, type                                                     node
# id                                                  693400858
# lat                                                 52.714753
# lon                                                  13.27509
# tags        {'addr:city': 'Hohen Neuendorf', 'addr:country...
# name                                            Villa Grünler
# category                                       [cafe, bakery]
# Name: 21161, dtype: object, type                                                     node
# id                                                  695831701
# lat                                                 52.497456
# lon                                                 13.295907
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                Tre Terre
# category                                         [cafe, deli]
# Name: 21164, dtype: object, type                                                     node
# id                                                  703501026
# lat                                                 52.543028
# lon                                                 13.412652
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Jute Bäckerei
# category                                       [cafe, bakery]
# Name: 21168, dtype: object, type                                                     node
# id                                                  721522044
# lat                                                 52.535385
# lon                                                 13.419929
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                     Manufacture Delicate
# category                                       [cafe, bakery]
# Name: 21184, dtype: object, type                                                     node
# id                                                  727852043
# lat                                                 52.494586
# lon                                                 13.354163
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                  Winterfeldt Schokoladen
# category                                [cafe, confectionery]
# Name: 21190, dtype: object, type                                                     node
# id                                                  752995885
# lat                                                  52.47375
# lon                                                 13.444794
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Gülays Kitchen
# category                                       [cafe, bakery]
# Name: 21212, dtype: object, type                                                     node
# id                                                  774485383
# lat                                                 52.540705
# lon                                                 13.415997
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Asmen Feinkost
# category                                         [cafe, deli]
# Name: 21224, dtype: object, type                                                     node
# id                                                  775342945
# lat                                                 52.458645
# lon                                                 13.322707
# tags        {'access:covid19': 'yes', 'amenity': 'cafe', '...
# name                                      Confiserie Reichert
# category                                [cafe, confectionery]
# Name: 21226, dtype: object, type                                                     node
# id                                                  778710965
# lat                                                 52.539385
# lon                                                 13.410318
# tags        {'amenity': 'cafe', 'cuisine': 'ice_cream', 'i...
# name                                                  Eis Bar
# category                                    [cafe, ice_cream]
# Name: 21233, dtype: object, type                                                     node
# id                                                  820548279
# lat                                                 52.517696
# lon                                                 13.290776
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                               Tee-o-d'or
# category                                     [cafe, gift;tea]
# Name: 21247, dtype: object, type                                                     node
# id                                                  831416217
# lat                                                 52.490287
# lon                                                 13.353398
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                              Tee Tea Thé
# category                                          [cafe, tea]
# Name: 21253, dtype: object, type                                                     node
# id                                                  832835292
# lat                                                 52.553163
# lon                                                 13.366135
# tags        {'amenity': 'cafe', 'ice_cream': 'yes', 'name'...
# name                                 Golden Bäcker & Eis Café
# category                                       [cafe, bakery]
# Name: 21254, dtype: object, type                                                     node
# id                                                  867734682
# lat                                                 52.502364
# lon                                                 13.416964
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                          ART en chocolat
# category                                [cafe, confectionery]
# Name: 21271, dtype: object, type                                                     node
# id                                                  881958859
# lat                                                 52.389806
# lon                                                 13.071509
# tags        {'addr:city': 'Potsdam', 'addr:country': 'DE',...
# name                                                    Exner
# category                                       [cafe, bakery]
# Name: 21277, dtype: object, type                                                     node
# id                                                  920664308
# lat                                                 52.498182
# lon                                                 13.384815
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Ökotussi
# category                                  [cafe, convenience]
# Name: 21289, dtype: object, type                                                     node
# id                                                  931622739
# lat                                                 52.484744
# lon                                                 13.443917
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '1...
# name                                              Zimt & Mehl
# category                                       [cafe, bakery]
# Name: 21296, dtype: object, type                                                     node
# id                                                  945649942
# lat                                                 52.534939
# lon                                                 13.417494
# tags        {'amenity': 'cafe', 'name': 'Cafe am Wassertur...
# name                                       Cafe am Wasserturm
# category                                       [cafe, bakery]
# Name: 21308, dtype: object, type                                                     node
# id                                                  978979323
# lat                                                 52.531606
# lon                                                 13.396236
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '1...
# name                                   Schneiders Schokoladen
# category                                [cafe, confectionery]
# Name: 21323, dtype: object, type                                                     node
# id                                                 1006711174
# lat                                                 52.437981
# lon                                                  13.29515
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '4...
# name                                               Frau Lüske
# category                                       [cafe, bakery]
# Name: 21335, dtype: object, type                                                     node
# id                                                 1075397105
# lat                                                 52.521854
# lon                                                  13.38456
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '9...
# name                               Sag mir wo die Blumen sind
# category                                       [cafe, bakery]
# Name: 21342, dtype: object, type                                                     node
# id                                                 1104699440
# lat                                                 52.371357
# lon                                                 13.134679
# tags        {'addr:city': 'Potsdam', 'addr:country': 'DE',...
# name                                                   Tchibo
# category                                       [cafe, coffee]
# Name: 21353, dtype: object, type                                                     node
# id                                                 1137567654
# lat                                                 52.474296
# lon                                                 13.332929
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                              Weinbeisser
# category                                      [cafe, alcohol]
# Name: 21365, dtype: object, type                                                     node
# id                                                 1154259642
# lat                                                 52.492359
# lon                                                 13.426202
# tags        {'amenity': 'cafe', 'name': 'Sing Blackbird', ...
# name                                           Sing Blackbird
# category                                      [cafe, clothes]
# Name: 21368, dtype: object, type                                                     node
# id                                                 1159055478
# lat                                                 52.528288
# lon                                                 13.424589
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                             Melis Coffee
# category                                       [cafe, bakery]
# Name: 21373, dtype: object, type                                                     node
# id                                                 1256737721
# lat                                                 52.494385
# lon                                                 13.416755
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            TEE·SALON·IKI
# category                                          [cafe, tea]
# Name: 21422, dtype: object, type                                                     node
# id                                                 1282042781
# lat                                                 52.589513
# lon                                                 13.282557
# tags        {'addr:housenumber': '5', 'addr:postcode': '13...
# name                                                    Altan
# category                                       [cafe, pastry]
# Name: 21430, dtype: object, type                                                     node
# id                                                 1305230458
# lat                                                 52.518208
# lon                                                 13.314804
# tags        {'amenity': 'cafe', 'name': 'Arrey', 'shop': '...
# name                                                    Arrey
# category                                       [cafe, bakery]
# Name: 21436, dtype: object, type                                                     node
# id                                                 1313503788
# lat                                                 52.513574
# lon                                                 13.294681
# tags        {'amenity': 'cafe', 'name': 'Selmani Bäckerei ...
# name                       Selmani Bäckerei & Konditorei Café
# category                                       [cafe, bakery]
# Name: 21447, dtype: object, type                                                     node
# id                                                 1348720482
# lat                                                  52.50154
# lon                                                 13.431923
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                  Jannimu
# category                                         [cafe, deli]
# Name: 21473, dtype: object, type                                                     node
# id                                                 1397070387
# lat                                                 52.504943
# lon                                                 13.367928
# tags        {'amenity': 'cafe', 'name': 'Staabi Back & Bis...
# name                               Staabi Back & Bistro Kiosk
# category                                  [cafe, convenience]
# Name: 21498, dtype: object, type                                                     node
# id                                                 1400842135
# lat                                                 52.562455
# lon                                                 13.096985
# tags        {'addr:housenumber': '44', 'addr:postcode': '1...
# name                                               Biofreunde
# category                                  [cafe, convenience]
# Name: 21499, dtype: object, type                                                     node
# id                                                 1433120465
# lat                                                 52.519203
# lon                                                 13.402645
# tags        {'amenity': 'cafe', 'cuisine': 'ice_cream', 'n...
# name                                             Bandy Brooks
# category                                    [cafe, ice_cream]
# Name: 21512, dtype: object, type                                                     node
# id                                                 1486087545
# lat                                                 52.552017
# lon                                                 13.431646
# tags        {'amenity': 'cafe', 'name': 'Emma T.', 'touris...
# name                                                  Emma T.
# category                                      [cafe, artwork]
# Name: 21530, dtype: object, type                                                     node
# id                                                 1601806281
# lat                                                 52.491092
# lon                                                 13.394098
# tags        {'addr:suburb': 'Kreuzberg', 'amenity': 'cafe'...
# name                                               Eliza Café
# category                                       [cafe, bakery]
# Name: 21569, dtype: object, type                                                     node
# id                                                 1617444761
# lat                                                 52.433736
# lon                                                   13.2868
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                      Bäckerei Bärenstark
# category                                       [cafe, bakery]
# Name: 21575, dtype: object, type                                                     node
# id                                                 1662725018
# lat                                                 52.369318
# lon                                                 12.924347
# tags        {'amenity': 'cafe', 'delivery:covid19': 'no', ...
# name                                                 Kirstein
# category                                       [cafe, bakery]
# Name: 21589, dtype: object, type                                                     node
# id                                                 1714250170
# lat                                                 52.522985
# lon                                                 13.382867
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                       Backshop Cafe am Deutschen Theater
# category                                       [cafe, bakery]
# Name: 21597, dtype: object, type                                                     node
# id                                                 1766031885
# lat                                                 52.498928
# lon                                                 13.421967
# tags        {'amenity': 'cafe', 'name': 'Alimentari e Vini...
# name                                        Alimentari e Vini
# category                                         [cafe, deli]
# Name: 21613, dtype: object, type                                                     node
# id                                                 1852738792
# lat                                                 52.494549
# lon                                                 13.358016
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Cafe Palladin
# category                                       [cafe, bakery]
# Name: 21645, dtype: object, type                                                     node
# id                                                 1964235485
# lat                                                 52.533161
# lon                                                 13.422673
# tags        {'amenity': 'cafe', 'internet_access': 'wlan',...
# name                                    Ralf's Torten Atelier
# category                                [cafe, confectionery]
# Name: 21702, dtype: object, type                                                     node
# id                                                 1976439629
# lat                                                 52.532745
# lon                                                 13.423872
# tags        {'amenity': 'cafe', 'name': 'Bäckerei', 'openi...
# name                                                 Bäckerei
# category                                       [cafe, bakery]
# Name: 21711, dtype: object, type                                                     node
# id                                                 2028823935
# lat                                                 52.481495
# lon                                                 13.363229
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                          Cafe Mon Cherie
# category                                       [cafe, bakery]
# Name: 21719, dtype: object, type                                                     node
# id                                                 2033281037
# lat                                                  52.50244
# lon                                                 13.316688
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                     SETs
# category                                  [cafe, guest_house]
# Name: 21721, dtype: object, type                                                     node
# id                                                 2060775214
# lat                                                 52.634391
# lon                                                 13.289981
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                   Lindner & Feinbäckerei
# category                                       [cafe, bakery]
# Name: 21724, dtype: object, type                                                     node
# id                                                 2073204042
# lat                                                 52.400678
# lon                                                 13.051856
# tags        {'access': 'customers', 'addr:city': 'Potsdam'...
# name                               DDR-Laden & Nostalgie-Café
# category                            [cafe, historic;regional]
# Name: 21727, dtype: object, type                                                     node
# id                                                 2095900330
# lat                                                 52.499313
# lon                                                 13.307515
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                     Aux Délices Normands
# category                                       [cafe, bakery]
# Name: 21729, dtype: object, type                                                     node
# id                                                 2102541972
# lat                                                 52.521226
# lon                                                 13.347677
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                           Bäckerei & Konditorei Buchwald
# category                                       [cafe, bakery]
# Name: 21733, dtype: object, type                                                     node
# id                                                 2264296523
# lat                                                 52.551865
# lon                                                 13.384018
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                    Il Milanese del Tacco
# category                                         [cafe, deli]
# Name: 21775, dtype: object, type                                                     node
# id                                                 2284912291
# lat                                                 52.503955
# lon                                                 13.330636
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                Ampelmann
# category                                         [cafe, gift]
# Name: 21778, dtype: object, type                                                     node
# id                                                 2444312258
# lat                                                 52.501168
# lon                                                 13.421124
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '2...
# name                                         Companion Coffee
# category                                          [cafe, tea]
# Name: 21843, dtype: object, type                                                     node
# id                                                 2634887161
# lat                                                 52.500322
# lon                                                 13.351124
# tags        {'amenity': 'cafe', 'internet_access': 'wlan',...
# name                                                 brotzeit
# category                                       [cafe, bakery]
# Name: 21911, dtype: object, type                                                     node
# id                                                 2642104003
# lat                                                  52.52194
# lon                                                 13.403163
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                       T2
# category                                          [cafe, tea]
# Name: 21916, dtype: object, type                                                     node
# id                                                 2752211177
# lat                                                 52.557339
# lon                                                 13.385637
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                    Petek
# category                                       [cafe, bakery]
# Name: 21936, dtype: object, type                                                     node
# id                                                 2764110685
# lat                                                 52.486663
# lon                                                 13.431051
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '6...
# name                                              Two and Two
# category                                   [cafe, stationery]
# Name: 21941, dtype: object, type                                                     node
# id                                                 2837335509
# lat                                                 52.504846
# lon                                                 13.357016
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                            Richter's Backshop & Stehcafé
# category                                       [cafe, bakery]
# Name: 21956, dtype: object, type                                                     node
# id                                                 2869920582
# lat                                                 52.536367
# lon                                                 13.180982
# tags        {'amenity': 'cafe', 'contact:phone': '+49 30 3...
# name                                                   Thoben
# category                                       [cafe, bakery]
# Name: 21964, dtype: object, type                                                     node
# id                                                 2950428546
# lat                                                 52.507753
# lon                                                 13.320682
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                         Dubenkropp Pralinen & Schokolade
# category                                [cafe, confectionery]
# Name: 21986, dtype: object, type                                                     node
# id                                                 3225776361
# lat                                                 52.471258
# lon                                                 13.385095
# tags        {'amenity': 'cafe', 'contact:facebook': 'https...
# name                                            Blue Eis-Café
# category                                       [cafe, coffee]
# Name: 22053, dtype: object, type                                                     node
# id                                                 3343659750
# lat                                                 52.498949
# lon                                                 13.362235
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                call+more
# category                                [cafe, internet_cafe]
# Name: 22088, dtype: object, type                                                     node
# id                                                 3354430613
# lat                                                 52.503199
# lon                                                 13.334854
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                         au petite delice
# category                                       [cafe, bakery]
# Name: 22093, dtype: object, type                                                     node
# id                                                 3354437236
# lat                                                 52.501461
# lon                                                 13.325314
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                  Berliner Kaffeerösterei
# category               [cafe, coffee_roasting; confectionary]
# Name: 22094, dtype: object, type                                                     node
# id                                                 3418098117
# lat                                                 52.678434
# lon                                                 13.588101
# tags        {'amenity': 'cafe', 'name': 'Cafe zum Hussiten...
# name                                        Cafe zum Hussiten
# category                                       [cafe, bakery]
# Name: 22110, dtype: object, type                                                     node
# id                                                 3474035719
# lat                                                 52.513334
# lon                                                  13.30437
# tags        {'amenity': 'cafe', 'name': 'Hellas Feinkost',...
# name                                          Hellas Feinkost
# category                                         [cafe, deli]
# Name: 22125, dtype: object, type                                                     node
# id                                                 3542703876
# lat                                                 52.500851
# lon                                                 13.299022
# tags        {'amenity': 'cafe', 'name': 'Berlin Coffee Clu...
# name                                       Berlin Coffee Club
# category                                   [cafe, accesoires]
# Name: 22150, dtype: object, type                                                     node
# id                                                 3666623788
# lat                                                 52.496212
# lon                                                 13.342829
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                             Viktoria Eis
# category                                    [cafe, ice_cream]
# Name: 22188, dtype: object, type                                                     node
# id                                                 3757048825
# lat                                                 52.402273
# lon                                                 13.542707
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                       Mama's Back+Bistro
# category                                       [cafe, bakery]
# Name: 22219, dtype: object, type                                                     node
# id                                                 3782374473
# lat                                                 52.501417
# lon                                                 13.330817
# tags        {'amenity': 'cafe', 'cuisine': 'italian', 'nam...
# name                                         Espresso Company
# category                                  [cafe, electronics]
# Name: 22234, dtype: object, type                                                     node
# ...
# lon                                                 13.202885
# tags        {'leaf_type': 'broadleaved', 'name': 'Mörderei...
# name                                              Mördereiche
# category                                   [tree, attraction]
# Name: 212355, dtype: object, type                                                     node
# id                                                 2966005919
# lat                                                 52.508526
# lon                                                 13.379683
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Wachturm
# category                               [historic, attraction]
# Name: 212356, dtype: object, type                                                     node
# id                                                 3871338319
# lat                                                 52.394348
# lon                                                 13.061233
# tags        {'genus': 'Tilia', 'image': 'https://upload.wi...
# name                                       Bittschriftenlinde
# category                                   [tree, attraction]
# Name: 212360, dtype: object, type                                                     node
# id                                                 4844728421
# lat                                                 52.509901
# lon                                                 13.376312
# tags        {'description': 'Remains of the Berlin Wall', ...
# name                                                      NaN
# category                               [historic, attraction]
# Name: 212367, dtype: object, type                                                     node
# id                                                 5479192054
# lat                                                 52.477594
# lon                                                 13.402207
# tags        {'historic': 'aircraft', 'name': 'Übungsflugze...
# name                    Übungsflugzeug der Flughafenfeuerwehr
# category                               [historic, attraction]
# Name: 212375, dtype: object, type                                                     node
# id                                                 6958744124
# lat                                                 52.514062
# lon                                                 13.711031
# tags        {'historic': 'yes', 'name': 'Gewölbekeller Bol...
# name                                Gewölbekeller Bollensdorf
# category                               [historic, attraction]
# Name: 212387, dtype: object, type                                                     node
# id                                                  410135935
# lat                                                 52.493327
# lon                                                  13.42749
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                    Studio für Gestaltung
# category                                 [beverages, gallery]
# Name: 212409, dtype: object, type                                                     node
# id                                                 1244787397
# lat                                                 52.498742
# lon                                                 13.442824
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                  Galerie Heba im Atelier
# category                                       [art, gallery]
# Name: 212420, dtype: object, type                                                     node
# id                                                 1478259435
# lat                                                 52.504552
# lon                                                 13.423755
# tags        {'amenity': 'arts_centre', 'name': 'Kunstraum ...
# name                                      Kunstraum Kreuzberg
# category                               [arts_centre, gallery]
# Name: 212424, dtype: object, type                                                     node
# id                                                 3478842464
# lat                                                 52.494809
# lon                                                 13.361363
# tags        {'craft': 'handicraft', 'name': 'Galierie Zwit...
# name                             Galierie Zwitscher Maschiene
# category                                       [art, gallery]
# Name: 212446, dtype: object, type                                                     node
# id                                                 3861765074
# lat                                                 52.503559
# lon                                                 13.324546
# tags        {'name': 'R & R Galerie', 'shop': 'frame', 'to...
# name                                            R & R Galerie
# category                                     [frame, gallery]
# Name: 212458, dtype: object, type                                                     node
# id                                                 4022570233
# lat                                                 52.526789
# lon                                                 13.388844
# tags        {'amenity': 'contemporary_art_gallery', 'name'...
# name                                        Galerie Eigenheim
# category             [contemporary_art_gallery, art, gallery]
# Name: 212460, dtype: object, type                                                     node
# id                                                 4331543099
# lat                                                  52.48974
# lon                                                  13.35388
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                 Galerie subje|ctobje|ct. art involvement
# category             [contemporary_art_gallery, art, gallery]
# Name: 212478, dtype: object, type                                                     node
# id                                                 4742923387
# lat                                                 52.502914
# lon                                                 13.409932
# tags        {'fee': 'no', 'name': 'Imago', 'opening_hours'...
# name                                                    Imago
# category                                     [photo, gallery]
# Name: 212487, dtype: object, type                                                     node
# id                                                 5763720229
# lat                                                 52.510733
# lon                                                 13.322852
# tags        {'addr:city': 'Berlin', 'addr:housenumber': '1...
# name                                             Bauhaus-Shop
# category                                     [books, gallery]
# Name: 212510, dtype: object, type                                                     node
# id                                                 2807527330
# lat                                                 52.501056
# lon                                                  13.42077
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                         Museum der Dinge
# category                                    [library, museum]
# Name: 212666, dtype: object, type                                                     node
# id                                                   30815438
# lat                                                 52.569974
# lon                                                 13.294091
# tags        {'amenity': 'shelter', 'shelter_type': 'Wetter...
# name                                                      NaN
# category                                 [shelter, viewpoint]
# Name: 212752, dtype: object, type                                                     node
# id                                                  156850034
# lat                                                 52.497718
# lon                                                 13.242954
# tags        {'ele': '120', 'name': 'Teufelsberg', 'natural...
# name                                              Teufelsberg
# category                                    [peak, viewpoint]
# Name: 212755, dtype: object, type                                                     node
# id                                                  277819122
# lat                                                 52.245381
# lon                                                 13.115907
# tags        {'leisure': 'bird_hide', 'name': 'Vogelbeobach...
# name                         Vogelbeobachtungsturm " Seechen"
# category                               [bird_hide, viewpoint]
# Name: 212768, dtype: object, type                                                     node
# id                                                  353075536
# lat                                                 52.502369
# lon                                                 13.248242
# tags        {'ele': '99', 'name': 'Drachenberg', 'natural'...
# name                                              Drachenberg
# category                                    [peak, viewpoint]
# Name: 212781, dtype: object, type                                                     node
# id                                                  358511526
# lat                                                 52.556313
# lon                                                 13.581791
# tags        {'ele': '114', 'image': 'http://i.imgur.com/yP...
# name                                 Großer Ahrensfelder Berg
# category                                    [peak, viewpoint]
# Name: 212783, dtype: object, type                                                     node
# id                                                  505157992
# lat                                                 52.622857
# lon                                                 13.459593
# tags        {'leisure': 'bird_hide', 'tourism': 'viewpoint...
# name                                                      NaN
# category                               [bird_hide, viewpoint]
# Name: 212801, dtype: object, type                                                     node
# id                                                  601506022
# lat                                                 52.622297
# lon                                                 13.458684
# tags        {'leisure': 'bird_hide', 'tourism': 'viewpoint...
# name                                                      NaN
# category                               [bird_hide, viewpoint]
# Name: 212804, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 212818, dtype: object, type                                                     node
# id                                                  972384735
# lat                                                 52.621887
# lon                                                  13.46125
# tags        {'leisure': 'bird_hide', 'tourism': 'viewpoint...
# name                                                      NaN
# category                               [bird_hide, viewpoint]
# Name: 212840, dtype: object, type                                                     node
# id                                                 1242574916
# lat                                                 52.432524
# lon                                                 13.421109
# tags        {'ele': '60', 'name': 'Britzer Höhe', 'natural...
# name                                             Britzer Höhe
# category                                    [peak, viewpoint]
# Name: 212849, dtype: object, type                                                     node
# id                                                 1314771015
# lat                                                 52.406385
# lon                                                 13.360376
# tags        {'ele': '64', 'name': 'Schlehenberg', 'natural...
# name                                             Schlehenberg
# category                                    [peak, viewpoint]
# Name: 212852, dtype: object, type                                                     node
# id                                                 1578634748
# lat                                                 52.487739
# lon                                                 13.381524
# tags        {'direction': '0-360', 'ele': '66', 'name': 'K...
# name                                                Kreuzberg
# category                                    [peak, viewpoint]
# Name: 212863, dtype: object, type                                                     node
# id                                                 2030947470
# lat                                                 52.360594
# lon                                                 13.065905
# tags        {'ele': '114.2', 'image': 'http://upload.wikim...
# name                                       Kleiner Ravensberg
# category                                    [peak, viewpoint]
# Name: 212875, dtype: object, type                                                     node
# id                                                 2822452585
# lat                                                 52.436259
# lon                                                 13.416899
# tags        {'ele': '63', 'name': 'Aussichtsberg', 'natura...
# name                                            Aussichtsberg
# category                                    [peak, viewpoint]
# Name: 212893, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# Name: 212895, dtype: object, type                                                     node
# id                                                 3694997470
# lat                                                 52.644586
# lon                                                 13.456778
# tags        {'description': 'Plattform zur Naturbeobachtun...
# name                                                      NaN
# category                           [wildlife_hide, viewpoint]
# Name: 212914, dtype: object, type                                               node
# id                                           3754423494
# lat                                           52.544541
# lon                                           13.579458
# tags        {'natural': 'peak', 'tourism': 'viewpoint'}
# name                                                NaN
# category                              [peak, viewpoint]
# Name: 212917, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 212933, dtype: object, type                                                     node
# id                                                 4770982225
# lat                                                 52.397892
# lon                                                  13.02751
# tags        {'amenity': 'clock', 'display': 'sundial', 'su...
# name                                                      NaN
# category                                   [clock, viewpoint]
# Name: 212936, dtype: object]
# 310

# %% [markdown]
# 'version2' contains 310 entries with double categories. Some of these categories are not from the scraped categories.

# %% [markdown]
# # Version 3

# %%
"""
Function to extract categories from the 'tags' column of any version of the dataframe (must be parsed in as argument)

It contains the dictionary and loop from earlier category extraction.

A 'tags' column in its original raw form is a prerequisite. 
Pandas must be imported as pd and numpy as np.

Looping through keys should be enough, so I have added the extra lines back in.

I have included a line that will record 'historic: yes' categories as 'historic' rather than 'yes'.

"""

def extract_categories(df):
    
    # make a copy of the dataframe
    new_df = df
    
    # create a new 'category' column / fill it with empty lists
    new_df['category'] = np.empty((len(new_df), 0)).tolist()
    
    # dictionary of category key/value pairs that were scraped
    categories = {'amenity': ['atm',
                          'bar',
                          'bench',
                          'cafe',
                          'drinking_water',
                          'ice_cream',
                          'nightclub',
                          'restaurant'
                         ],
              
              'historic': 'yes',
              'leisure': 'picnic_table',
              'natural': 'tree',
              'shop':'convenience',
              'tourism': ['art_work',
                          'attraction',
                          'gallery',
                          'museum',
                          'viewpoint',
                          ]
              }

    # for the new df copy, loop through the 'tags' column, keeping track of the row index
    for index, row in enumerate(new_df.tags):        
        # for each row, loop through every key in the 'categories' dictionary
        for key in categories:
            # if the row contains a matching key
            if key in row:
                # if the key's value is equal to 'historic'
                if key == 'historic':
                    # for the current row, append 'historic' to the 'category' column
                    new_df.loc[index, 'category'].append('historic')
                else:
                    # check the key's value from the row against the key's values from the 'categories' variable
                    for value in categories[key]:
                        # if there is a match
                        if value in row[key]:
                            # for the current row, append the key's value to the 'category' column
                            new_df.loc[index, 'category'].append(row[key])
                     
    return new_df

# %%
# loop through every row in all_nodes.tags, keeping track of the index
for index, row in enumerate(all_nodes.tags):
    # for each row, loop through every key from the 'categories' variable 
    for key in categories:
        # if the row contains a matching key    
        if key in row:
            # check the key's value from the row against the key's values from the 'categories' variable
            for value in categories[key]:
                # if these check out
                if value in row[key]:
                    # for the current row, add the value to a new 'category' column
                    all_nodes.loc[index, 'category'] = row[key]

# %%
version3 = extract_categories(all_nodes)
version3
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name     category
# 0       Bank für Sozialwirtschaft        [atm]
# 1                     Sparda-Bank        [atm]
# 2            Bankhaus August Lenz        [atm]
# 3                             NaN        [atm]
# 4              Berliner Sparkasse        [atm]
# ...                           ...          ...
# 213006                        NaN  [viewpoint]
# 213007                        NaN  [viewpoint]
# 213008                Alpengipfel  [viewpoint]
# 213009                        NaN  [viewpoint]
# 213010                        NaN  [viewpoint]
#
# [213011 rows x 7 columns]

# %%
double_categories2 = []
for index, value in enumerate(version3.category):
    if len(value) > 1:
      
        double_categories2.append(version3.iloc[index])
        
print(double_categories2)
len(double_categories2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 183816

# %%
version3.iloc[1041]
# Out:
# type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# Name: 1041, dtype: object

# %%
version3.iloc[1083]
# Out:
# type                                                     node
# id                                                  667858502
# lat                                                 52.503265
# lon                                                 13.412501
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Hürrem Sultan
# category                                [bar, tailor, tailor]
# Name: 1083, dtype: object

# %%
version3.iloc[1303]
# Out:
# type                                                     node
# id                                                 2541047698
# lat                                                 52.470828
# lon                                                 13.441197
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                               Café & Bar
# category    [bar, adult_gaming_center, adult_gaming_center...
# Name: 1303, dtype: object

# %% [markdown]
# # Version 4

# %%
"""
Function to extract categories from the 'tags' column of any version of the dataframe (must be parsed in as argument)

It contains the dictionary and loop from earlier category extraction.

A 'tags' column in its original raw form is a prerequisite. 
Pandas must be imported as pd and numpy as np.

Looping through keys should be enough, so I have added the extra lines back in.

I have included a line that will record 'historic: yes' categories as 'historic' rather than 'yes'.

"""

def extract_categories4(df):
    
    # make a copy of the dataframe
    new_df = df
    
    # create a new 'category' column / fill it with empty lists
    new_df['category'] = np.empty((len(new_df), 0)).tolist()
    
    # dictionary of category key/value pairs that were scraped
    categories = {'amenity': ['atm',
                          'bar',
                          'bench',
                          'cafe',
                          'drinking_water',
                          'ice_cream',
                          'nightclub',
                          'restaurant'
                         ],
              
              'historic': ['yes'], # fixed bug to put all values into lists to avoid looping on strings
              'leisure': ['picnic_table'],
              'natural': ['tree'],
              'shop': ['convenience'],
              'tourism': ['art_work',
                          'attraction',
                          'gallery',
                          'museum',
                          'viewpoint',
                          ] 
              }

    # for the new df copy, loop through the 'tags' column, keeping track of the row index
    for index, row in enumerate(new_df.tags):        
        # for each row, loop through every key in the 'categories' dictionary
        for key in categories:
            # if the row contains a matching key
            if key in row:
                # if the key's value is equal to 'historic'
                if key == 'historic':
                    # for the current row, append 'historic' to the 'category' column
                    new_df.loc[index, 'category'].append('historic')
                else:
                    # check the key's value from the row against the key's values from the 'categories' variable
                    for value in categories[key]:
                        # if there is a match
                        if value in row[key]:
                            # for the current row, append the key's value to the 'category' column
                            new_df.loc[index, 'category'].append(value) # fixed bug to add matched value only
                     
    return new_df

# %%
version4 = extract_categories4(all_nodes)
all_nodes
# Out:
#         type          id        lat        lon  \
# 0       node    78252154  52.523744  13.398627
# 1       node    87036263  52.532985  13.384282
# 2       node    89275133  52.518025  13.406956
# 3       node   213106623  52.542170  13.441137
# 4       node   213113204  52.542750  13.392862
# ...      ...         ...        ...        ...
# 213006  node  8931299152  52.487989  13.275393
# 213007  node  9024702237  52.506772  13.334563
# 213008  node  9026936271  52.401704  13.366960
# 213009  node  9038673666  52.482133  13.291911
# 213010  node  9180246277  52.363764  13.533663
#
#                                                      tags  \
# 0       {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# 1       {'amenity': 'atm', 'brand': 'Sparda-Bank', 'br...
# 2       {'amenity': 'atm', 'name': 'Bankhaus August Le...
# 3       {'addr:country': 'DE', 'addr:housenumber': '87...
# 4       {'amenity': 'atm', 'name': 'Berliner Sparkasse...
# ...                                                   ...
# 213006                           {'tourism': 'viewpoint'}
# 213007                           {'tourism': 'viewpoint'}
# 213008    {'name': 'Alpengipfel', 'tourism': 'viewpoint'}
# 213009         {'direction': 'E', 'tourism': 'viewpoint'}
# 213010  {'description': 'Plane spotting östlich der Sü...
#
#                              name     category
# 0       Bank für Sozialwirtschaft        [atm]
# 1                     Sparda-Bank        [atm]
# 2            Bankhaus August Lenz        [atm]
# 3                             NaN        [atm]
# 4              Berliner Sparkasse        [atm]
# ...                           ...          ...
# 213006                        NaN  [viewpoint]
# 213007                        NaN  [viewpoint]
# 213008                Alpengipfel  [viewpoint]
# 213009                        NaN  [viewpoint]
# 213010                        NaN  [viewpoint]
#
# [213011 rows x 7 columns]

# %%
double_categories4 = []
for index, value in enumerate(version4.category):
    if len(value) > 1:
      
        double_categories4.append(version4.iloc[index])
        
print(double_categories4)
len(double_categories4)
# Out:
# [type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# Name: 1041, dtype: object, type                                                     node
# id                                                  746853061
# lat                                                 52.580255
# lon                                                 13.398819
# tags        {'amenity': 'bar', 'internet_access': 'termina...
# name                                         Babylon Café Bar
# category                                   [bar, convenience]
# Name: 1098, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# Name: 1344, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 2305, dtype: object, type                                                     node
# id                                                  942863082
# lat                                                 52.357758
# lon                                                 13.472117
# tags        {'amenity': 'bench', 'backrest': 'yes', 'colou...
# name                                                      NaN
# category                                        [bench, tree]
# Name: 2797, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 8365, dtype: object, type                                                     node
# id                                                  920664308
# lat                                                 52.498182
# lon                                                 13.384815
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Ökotussi
# category                                  [cafe, convenience]
# Name: 21289, dtype: object, type                                                     node
# id                                                 1397070387
# lat                                                 52.504943
# lon                                                 13.367928
# tags        {'amenity': 'cafe', 'name': 'Staabi Back & Bis...
# name                               Staabi Back & Bistro Kiosk
# category                                  [cafe, convenience]
# Name: 21498, dtype: object, type                                                     node
# id                                                 1400842135
# lat                                                 52.562455
# lon                                                 13.096985
# tags        {'addr:housenumber': '44', 'addr:postcode': '1...
# name                                               Biofreunde
# category                                  [cafe, convenience]
# Name: 21499, dtype: object, type                                                     node
# id                                                 3855567146
# lat                                                 52.497329
# lon                                                 13.361518
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                    DiVan
# category                                  [cafe, convenience]
# Name: 22267, dtype: object, type                                                     node
# id                                                 6596706590
# lat                                                 52.545928
# lon                                                 13.344898
# tags        {'amenity': 'cafe', 'name': 'Von morgens bis S...
# name                                    Von morgens bis Späti
# category                                  [cafe, convenience]
# Name: 22987, dtype: object, type                                              node
# id                                          9201250436
# lat                                          52.571576
# lon                                           13.37374
# tags        {'amenity': 'cafe', 'shop': 'convenience'}
# name                                               NaN
# category                           [cafe, convenience]
# Name: 23319, dtype: object, type                                                     node
# id                                                 1110086631
# lat                                                  52.50532
# lon                                                 13.394087
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Super Ibérico
# category                            [restaurant, convenience]
# Name: 25336, dtype: object, type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# Name: 28608, dtype: object, type                                                     node
# id                                                 2966005919
# lat                                                 52.508526
# lon                                                 13.379683
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Wachturm
# category                               [historic, attraction]
# Name: 28630, dtype: object, type                                                     node
# id                                                 6958744124
# lat                                                 52.514062
# lon                                                 13.711031
# tags        {'historic': 'yes', 'name': 'Gewölbekeller Bol...
# name                                Gewölbekeller Bollensdorf
# category                               [historic, attraction]
# Name: 28658, dtype: object, type                                                     node
# id                                                 6486438639
# lat                                                 52.483408
# lon                                                 13.186136
# tags        {'amenity': 'bench;table', 'leisure': 'picnic_...
# name                                                      NaN
# category                                [bench, picnic_table]
# Name: 28881, dtype: object, type                                                     node
# id                                                 6486438642
# lat                                                 52.484285
# lon                                                 13.185957
# tags        {'amenity': 'bench;table', 'leisure': 'picnic_...
# name                                                      NaN
# category                                [bench, picnic_table]
# Name: 28882, dtype: object, type                                                     node
# id                                                  205066401
# lat                                                 52.593577
# lon                                                 13.264907
# tags        {'circumference': '6.65', 'denotation': 'natur...
# name                                              Dicke Marie
# category                                   [tree, attraction]
# Name: 29129, dtype: object, type                                                     node
# id                                                  268462839
# lat                                                 52.540259
# lon                                                 13.811659
# tags        {'name': 'Eiche', 'natural': 'tree', 'tourism'...
# name                                                    Eiche
# category                                   [tree, attraction]
# Name: 29136, dtype: object, type                                                     node
# id                                                  518017139
# lat                                                 52.099379
# lon                                                 12.875652
# tags        {'name': 'Lutherlinde', 'natural': 'tree', 'to...
# name                                              Lutherlinde
# category                                   [tree, attraction]
# Name: 29482, dtype: object, type                                                     node
# id                                                  685046490
# lat                                                 52.369825
# lon                                                 13.271988
# tags        {'denotation': 'natural_monument', 'genus': 'T...
# name                                         Bernadotte Linde
# category                                   [tree, attraction]
# Name: 30394, dtype: object, type                                                     node
# id                                                  732329248
# lat                                                 52.655285
# lon                                                 13.070655
# tags        {'genus': 'Fagus', 'genus:de': 'Buche', 'leaf_...
# name                                       Zwölf Brüder Buche
# category                                   [tree, attraction]
# Name: 30638, dtype: object, type                                                     node
# id                                                  867885897
# lat                                                 52.501682
# lon                                                 13.415536
# tags        {'description': 'Gedenkbaum für die Opfer des ...
# name                                                      NaN
# category                                     [historic, tree]
# Name: 30663, dtype: object, type                                                     node
# id                                                  942863082
# lat                                                 52.357758
# lon                                                 13.472117
# tags        {'amenity': 'bench', 'backrest': 'yes', 'colou...
# name                                                      NaN
# category                                        [bench, tree]
# Name: 30670, dtype: object, type                                                     node
# id                                                 1609064712
# lat                                                 52.595351
# lon                                                 13.243543
# tags        {'description': 'Höchster Baum Berlins', 'genu...
# name              Lärche, der höchste Baum Berlins mit 42,5 m
# category                                   [tree, attraction]
# Name: 34220, dtype: object, type                                                     node
# id                                                 2900844067
# lat                                                 52.427128
# lon                                                 13.048986
# tags        {'name': 'Baumhaus', 'natural': 'tree', 'playg...
# name                                                 Baumhaus
# category                                   [tree, attraction]
# Name: 50052, dtype: object, type                                                     node
# id                                                 2939703373
# lat                                                 52.260367
# lon                                                 13.202885
# tags        {'leaf_type': 'broadleaved', 'name': 'Mörderei...
# name                                              Mördereiche
# category                                   [tree, attraction]
# Name: 50113, dtype: object, type                                                     node
# id                                                 3871338319
# lat                                                 52.394348
# lon                                                 13.061233
# tags        {'genus': 'Tilia', 'image': 'https://upload.wi...
# name                                       Bittschriftenlinde
# category                                   [tree, attraction]
# Name: 97723, dtype: object, type                                                     node
# id                                                 7146216585
# lat                                                 52.165527
# lon                                                 12.853716
# tags        {'description:de': 'Linde wurde anlässlich des...
# name                                              Luisenlinde
# category                                     [historic, tree]
# Name: 183443, dtype: object, type                                                     node
# id                                                  746853061
# lat                                                 52.580255
# lon                                                 13.398819
# tags        {'amenity': 'bar', 'internet_access': 'termina...
# name                                         Babylon Café Bar
# category                                   [bar, convenience]
# Name: 211502, dtype: object, type                                                     node
# id                                                  920664308
# lat                                                 52.498182
# lon                                                 13.384815
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Ökotussi
# category                                  [cafe, convenience]
# Name: 211522, dtype: object, type                                                     node
# id                                                 1110086631
# lat                                                  52.50532
# lon                                                 13.394087
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Super Ibérico
# category                            [restaurant, convenience]
# Name: 211534, dtype: object, type                                                     node
# id                                                 1397070387
# lat                                                 52.504943
# lon                                                 13.367928
# tags        {'amenity': 'cafe', 'name': 'Staabi Back & Bis...
# name                               Staabi Back & Bistro Kiosk
# category                                  [cafe, convenience]
# Name: 211588, dtype: object, type                                                     node
# id                                                 1400842135
# lat                                                 52.562455
# lon                                                 13.096985
# tags        {'addr:housenumber': '44', 'addr:postcode': '1...
# name                                               Biofreunde
# category                                  [cafe, convenience]
# Name: 211590, dtype: object, type                                                     node
# id                                                 2496841605
# lat                                                 52.510136
# lon                                                 13.458375
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                              Quick Store Aquarium Lounge
# category                                  [cafe, convenience]
# Name: 211728, dtype: object, type                                                     node
# id                                                 3855567146
# lat                                                 52.497329
# lon                                                 13.361518
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                    DiVan
# category                                  [cafe, convenience]
# Name: 211853, dtype: object, type                                                     node
# id                                                 3914046328
# lat                                                 52.452421
# lon                                                   13.3334
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 @lbrecht
# category                                  [cafe, convenience]
# Name: 211865, dtype: object, type                                                     node
# id                                                 4331556368
# lat                                                 52.481255
# lon                                                 13.320116
# tags        {'amenity': 'internet_cafe', 'internet_access'...
# name                          Aris Internet-Spätkauf & Presse
# category                                  [cafe, convenience]
# Name: 211927, dtype: object, type                                                     node
# id                                                 6596706590
# lat                                                 52.545928
# lon                                                 13.344898
# tags        {'amenity': 'cafe', 'name': 'Von morgens bis S...
# name                                    Von morgens bis Späti
# category                                  [cafe, convenience]
# Name: 212129, dtype: object, type                                                     node
# id                                                 8147270778
# lat                                                 52.480708
# lon                                                 13.351453
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                Fast Shop
# category                                  [cafe, convenience]
# Name: 212216, dtype: object, type                                              node
# id                                          9201250436
# lat                                          52.571576
# lon                                           13.37374
# tags        {'amenity': 'cafe', 'shop': 'convenience'}
# name                                               NaN
# category                           [cafe, convenience]
# Name: 212287, dtype: object, type                                                     node
# id                                                   51501652
# lat                                                 52.655049
# lon                                                 13.719846
# tags        {'historic': 'memorial', 'name': 'Gedenkstätte...
# name                   Gedenkstätte Internierungslager Weesow
# category                               [historic, attraction]
# Name: 212293, dtype: object, type                                                     node
# id                                                  205066401
# lat                                                 52.593577
# lon                                                 13.264907
# tags        {'circumference': '6.65', 'denotation': 'natur...
# name                                              Dicke Marie
# category                                   [tree, attraction]
# Name: 212296, dtype: object, type                                                     node
# id                                                  267113400
# lat                                                  52.31816
# lon                                                 13.632617
# tags        {'description': 'technical_monument', 'histori...
# name                                    Dampflokomotive BR 52
# category                               [historic, attraction]
# Name: 212297, dtype: object, type                                                     node
# id                                                  268462839
# lat                                                 52.540259
# lon                                                 13.811659
# tags        {'name': 'Eiche', 'natural': 'tree', 'tourism'...
# name                                                    Eiche
# category                                   [tree, attraction]
# Name: 212298, dtype: object, type                                                     node
# id                                                  518017139
# lat                                                 52.099379
# lon                                                 12.875652
# tags        {'name': 'Lutherlinde', 'natural': 'tree', 'to...
# name                                              Lutherlinde
# category                                   [tree, attraction]
# Name: 212309, dtype: object, type                                                     node
# id                                                  558158766
# lat                                                 52.540486
# lon                                                 13.489519
# tags        {'historic': 'memorial', 'memorial': 'war_memo...
# name                                    Sowjetisches Ehrenmal
# category                               [historic, attraction]
# Name: 212311, dtype: object, type                                                     node
# id                                                  639131685
# lat                                                 52.418807
# lon                                                 13.171892
# tags        {'historic': 'memorial', 'image': 'http://comm...
# name                                               Kleistgrab
# category                               [historic, attraction]
# Name: 212316, dtype: object, type                                                     node
# id                                                  685046490
# lat                                                 52.369825
# lon                                                 13.271988
# tags        {'denotation': 'natural_monument', 'genus': 'T...
# name                                         Bernadotte Linde
# category                                   [tree, attraction]
# Name: 212317, dtype: object, type                                                     node
# id                                                  732329248
# lat                                                 52.655285
# lon                                                 13.070655
# tags        {'genus': 'Fagus', 'genus:de': 'Buche', 'leaf_...
# name                                       Zwölf Brüder Buche
# category                                   [tree, attraction]
# Name: 212319, dtype: object, type                                                     node
# id                                                 1166456006
# lat                                                 52.430757
# lon                                                 13.311793
# tags        {'description': 'Historische Treidellokomotive...
# name                                        Treidellokomotive
# category                               [historic, attraction]
# Name: 212322, dtype: object, type                                                     node
# id                                                 1589171931
# lat                                                 52.478944
# lon                                                 13.344614
# tags        {'description:de': 'Preußischer Ganzmeilenstei...
# name                                  Preußischer Meilenstein
# category                               [historic, attraction]
# Name: 212326, dtype: object, type                                                     node
# id                                                 1609064712
# lat                                                 52.595351
# lon                                                 13.243543
# tags        {'description': 'Höchster Baum Berlins', 'genu...
# name              Lärche, der höchste Baum Berlins mit 42,5 m
# category                                   [tree, attraction]
# Name: 212327, dtype: object, type                                                     node
# id                                                 2787929162
# lat                                                 52.408512
# lon                                                 13.302128
# tags        {'historic': 'memorial', 'memorial': 'plaque',...
# name                                 TV-Asahi-Kirschblütenweg
# category                               [historic, attraction]
# Name: 212344, dtype: object, type                                                     node
# id                                                 2900844067
# lat                                                 52.427128
# lon                                                 13.048986
# tags        {'name': 'Baumhaus', 'natural': 'tree', 'playg...
# name                                                 Baumhaus
# category                                   [tree, attraction]
# Name: 212353, dtype: object, type                                                     node
# id                                                 2939703373
# lat                                                 52.260367
# lon                                                 13.202885
# tags        {'leaf_type': 'broadleaved', 'name': 'Mörderei...
# name                                              Mördereiche
# category                                   [tree, attraction]
# Name: 212355, dtype: object, type                                                     node
# id                                                 2966005919
# lat                                                 52.508526
# lon                                                 13.379683
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                                 Wachturm
# category                               [historic, attraction]
# Name: 212356, dtype: object, type                                                     node
# id                                                 3871338319
# lat                                                 52.394348
# lon                                                 13.061233
# tags        {'genus': 'Tilia', 'image': 'https://upload.wi...
# name                                       Bittschriftenlinde
# category                                   [tree, attraction]
# Name: 212360, dtype: object, type                                                     node
# id                                                 4844728421
# lat                                                 52.509901
# lon                                                 13.376312
# tags        {'description': 'Remains of the Berlin Wall', ...
# name                                                      NaN
# category                               [historic, attraction]
# Name: 212367, dtype: object, type                                                     node
# id                                                 5479192054
# lat                                                 52.477594
# lon                                                 13.402207
# tags        {'historic': 'aircraft', 'name': 'Übungsflugze...
# name                    Übungsflugzeug der Flughafenfeuerwehr
# category                               [historic, attraction]
# Name: 212375, dtype: object, type                                                     node
# id                                                 6958744124
# lat                                                 52.514062
# lon                                                 13.711031
# tags        {'historic': 'yes', 'name': 'Gewölbekeller Bol...
# name                                Gewölbekeller Bollensdorf
# category                               [historic, attraction]
# Name: 212387, dtype: object, type                                                     node
# id                                                  701732373
# lat                                                 52.575659
# lon                                                 13.562247
# tags        {'amenity': 'bench', 'backrest': 'no', 'check_...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 212818, dtype: object, type                                                     node
# id                                                 2941462114
# lat                                                 52.482071
# lon                                                 13.431332
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                           Klunkerkranich
# category                                     [bar, viewpoint]
# Name: 212895, dtype: object, type                                                     node
# id                                                 4715040092
# lat                                                 52.622762
# lon                                                 13.339663
# tags        {'access': 'yes', 'amenity': 'bench', 'backres...
# name                                                      NaN
# category                                   [bench, viewpoint]
# Name: 212933, dtype: object]
# 65

# %%
version4.iloc[1041]
# Out:
# type                                                     node
# id                                                  429741495
# lat                                                 52.528762
# lon                                                 13.408603
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Kaffee Burger
# category                                      [bar, historic]
# Name: 1041, dtype: object

# %%
version4.iloc[1083]
# Out:
# type                                                     node
# id                                                  667858502
# lat                                                 52.503265
# lon                                                 13.412501
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                            Hürrem Sultan
# category                                                [bar]
# Name: 1083, dtype: object

# %%
version4.iloc[1303]
# Out:
# type                                                     node
# id                                                 2541047698
# lat                                                 52.470828
# lon                                                 13.441197
# tags        {'addr:city': 'Berlin', 'addr:country': 'DE', ...
# name                                               Café & Bar
# category                                                [bar]
# Name: 1303, dtype: object
